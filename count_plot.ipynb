# %%
# count plot examples

import matplotlib.pyplot as plt
import seaborn as sns

df = sns.load_dataset('mpg')

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
# basic count plot

custom_colors = ['#FF6347', '#4682B4', '#FFD700', '#ADFF2F', '#FF69B4']  # Custom colors for each 'cut'

sns.catplot(x='cylinders', data=df, kind='count', hue='cylinders', palette=custom_colors)
plt.show()

# %%
# horizontal count plot

sns.catplot(y='cylinders', data=df, kind='count', hue='cylinders', palette=custom_colors)
plt.show()

# %%
# horizontal count plot with sub plots

sns.catplot(y='cylinders', data=df, kind='count', col='origin', hue='cylinders', palette=custom_colors)
plt.show()
